# %% [markdown]
# # Notebook for testing purpose

# %%
from portfolio.stock import Stock

stock = Stock(ticker = "MSFT")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from umbrella_portfolio_manager.portfolio.portfolio import Portfolio
#       3 stock = Stock(ticker = "MSFT")
#
# ModuleNotFoundError: No module named 'umbrella_portfolio_manager.portfolio'; 'umbrella_portfolio_manager' is not a package

# %%
stock.ohlcv_history
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-02-10 00:00:00-05:00  259.231420  261.768917  258.369071  260.787628
# 2023-02-13 00:00:00-05:00  265.287745  272.186565  264.802031  268.935394
# 2023-02-14 00:00:00-05:00  270.273529  272.553302  266.913309  269.777924
# 2023-02-15 00:00:00-05:00  266.627888  269.022694  264.501369  267.621582
# 2023-02-16 00:00:00-05:00  262.354998  265.057846  260.248372  260.496796
# ...                               ...         ...         ...         ...
# 2024-02-05 00:00:00-05:00  409.899994  411.160004  403.989990  405.649994
# 2024-02-06 00:00:00-05:00  405.880005  407.970001  402.910004  405.489990
# 2024-02-07 00:00:00-05:00  407.440002  414.299988  407.399994  414.049988
# 2024-02-08 00:00:00-05:00  414.049988  415.559998  412.529999  414.109985
# 2024-02-09 00:00:00-05:00  415.250000  420.820007  415.089996  420.549988
#
#                              Volume
# Date
# ...
